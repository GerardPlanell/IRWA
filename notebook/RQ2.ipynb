# %%
#!pip install nltk

#nltk.download('stopwords');

# %%
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
import nltk
import time
from collections import defaultdict
from array import array
from nltk.stem import PorterStemmer
from nltk.corpus import stopwords
import math
import numpy as np
import matplotlib.pyplot as plt
import collections
from numpy import linalg as la
import pandas as pd
import re

# %% [markdown]
# Load tweets from local: for now we use the lab1 loading for reference

# %%
# Load data
csv_file_data = 'Data/Output_v5_data_anonim.csv'
data_raw = pd.read_csv(csv_file_data, quotechar='"',low_memory=False)
#print(data_raw)

csv_file_hashtag = 'Data/Output_v5_hash_anonim.csv'
hashtags_raw =pd.read_csv(csv_file_hashtag, quotechar='"',low_memory=False)
#print(hashtags_raw)

# %%
data_raw.head()
# Out:
#    tweet_id                                               text  \
# 0         1  The polls are absolutely wrong! All you have t...
# 1         8   _Lai And the dangerous part? When there is pu...
# 2        19  News flash. tRump IS a politician. https://t.c...
# 3        35  #NewYorkPost published a report saying e-mails...
# 4        39   @realDonaldTrump    @JoeBiden GOP HAS APPOINT...
#
#                    user_screen_name                      created_at  \
# 0  590ecf4c5b88c57f5658f3097f32efd2  Tue Oct 20 15:11:08 +0000 2020
# 1  203afe8023cab3bb1fa15ec48c737a71  Tue Oct 20 15:10:48 +0000 2020
# 2  a708a5aef0063b7a40cd2bbbf51984c0  Tue Oct 20 15:10:10 +0000 2020
# 3  c1170c45d30c5a1c258ba52e5e8349f6  Tue Oct 20 15:09:31 +0000 2020
# 4  2d9df2e6b9ecba9c119fc674c211b5ec  Tue Oct 20 15:09:14 +0000 2020
#
#    favorite_count  retweet_count  user_followers  \
# 0               0              0               3
# 1              18              1            2502
# 2               1              0             275
# 3               1              1             106
# 4               0              0             197
#
#                                                  url  user_followers_index
# 0  https://twitter.com/twitter/statuses/131857045...              0.832457
# 1  https://twitter.com/twitter/statuses/131857037...              0.915293
# 2  https://twitter.com/twitter/statuses/131857020...              0.845215
# 3  https://twitter.com/twitter/statuses/131857004...              0.837466
# 4  https://twitter.com/twitter/statuses/131856997...              0.841707

# %%
hashtags_raw.head()
# Out:
#    tweet_id            hastags
# 0        35        NewYorkPost
# 1        35           JoeBiden
# 2        35        HunterBiden
# 3        35           BREAKING
# 4        35  Hunterbidenlaptop

# %%
hashtags_raw = hashtags_raw.groupby(['tweet_id'])['hastags'].apply(', '.join).reset_index()

data = data_raw.merge(hashtags_raw, on='tweet_id',how='left')

data = data.sort_values(by=['tweet_id'])

data.rename(columns={'hastags':'hashtags'},inplace=True)

data.head()

#for trying
data = data[:15000]

#hashtags_raw.head()

# %%
data.iloc[21]
# Out:
# tweet_id                                                              272
# text                     I'm pretty happy to hear that #8 supports the...
# user_screen_name                         998be0e4bcfebf7245ac684c4e6037df
# created_at                                 Tue Oct 20 14:54:10 +0000 2020
# favorite_count                                                          0
# retweet_count                                                           0
# user_followers                                                        175
# url                     https://twitter.com/twitter/statuses/131856618...
# user_followers_index                                             0.840697
# hashtags                                                              NaN
# Name: 21, dtype: object

# %% [markdown]
# Functions:
#     - getTerms(line)  --> extract tweet items
#     - create_index(lines) --> get dictionaries
#     - search(query, index) --> busca docs que contienen todos los elementos de la query
#
# En cuanto tengamos la estructura de los tweets tendremos que modificar getTerms (getTerms(tweets)) y create_index (create_index(tweets)) para que se adapten a la estructura y construyan los diccionarios con lo que queremos.

# %% [markdown]
# # Index functions

# %%
def getTerms():
    """
    Preprocess the article text (title + body) removing stop words, stemming,
    transforming in lowercase and return the tokens of the text.
    
    Argument:
    line -- string (text) to be preprocessed
    
    Returns:
    line - a list of tokens corresponding to the input text after the preprocessing
    """
    global data
    data['words'] = data['text'].str.lower()

    # Special characters removal (mentions, URLs, punctuation and rt)
    data['words'] = data['words'].apply(lambda x: re.sub(r"([^0-9A-Za-z \t])|(\w+:\/\/\S+)|^rt|http.+?", "", x))  
    data['words'] = data['words'].str.split()
    # Stopwords removal
    stop = set(stopwords.words("english"))
    data['words'] = data['words'].apply(lambda x:([y for y in x if y not in stop]))
    # Stemming
    stemming = PorterStemmer()
    data['words'] = data['words'].apply(lambda x: ([stemming.stem(word) for word in x]))

# %%
getTerms()

# %%
def getTerms_str(line):
    """
    Preprocess the article text (title + body) removing stop words, stemming,
    transforming in lowercase and return the tokens of the text.
    
    Argument:
    line -- string (text) to be preprocessed
    
    Returns:
    line - a list of tokens corresponding to the input text after the preprocessing
    """
        
    stemming = PorterStemmer()
    stops = set(stopwords.words("english"))
    ## START CODE
    line = line.lower() ## Transform in lowercase
    line = re.sub(r"([^0-9A-Za-z \t])|(\w+:\/\/\S+)|^rt|http.+?", "", line)
    line = line.split() ## Tokenize the text to get a list of terms
    line = [term for term in line if term not in stops]  ##eliminate the stopwords (HINT: use List Comprehension)
    line =[stemming.stem(term) for term in line] ## perform stemming (HINT: use List Comprehension)
    ## END CODE
    return line

# %%
def create_index_tfidf():
    """
    Implement the inverted index and compute tf, df and idf
    
    Argument:
    lines -- collection of Wikipedia articles
    numDocuments -- total number of documents
    
    Returns:
    index - the inverted index (implemented through a python dictionary) containing terms as keys and the corresponding 
    list of document these keys appears in (and the positions) as values.
    tf - normalized term frequency for each term in each document
    df - number of documents each term appear in
    idf - inverse document frequency of each term
    """
    global data

    numDocuments=len(data.index)
    
    index=defaultdict(list)
    tf=defaultdict(list) #term frequencies of terms in documents (documents in the same order as in the main index)
    df=defaultdict(int)         #document frequencies of terms in the corpus
    idf=defaultdict(float)

    for num, row in data.iterrows():

        page_id = row['tweet_id']       
        terms = row['words'] #page_title + page_text
       
        
        ## ===============================================================        
        ## create the index for the **current page** and store it in termdictPage
        ## termdictPage ==> { ‘term1’: [currentdoc, [list of positions]], ...,‘termn’: [currentdoc, [list of positions]]}
        
        ## Example: if the curr_doc has id 1 and his text is 
        ## "web retrieval information retrieval":
        
        ## termdictPage ==> { ‘web’: [1, [0]], ‘retrieval’: [1, [1,4]], ‘information’: [1, [2]]}
        
        ## the term ‘web’ appears in document 1 in positions 0, 
        ## the term ‘retrieval’ appears in document 1 in positions 1 and 4
        ## ===============================================================

        termdictPage={}

        for position, term in enumerate(terms): ## terms contains page_title + page_text
            try:
                # if the term is already in the dict append the position to the corrisponding list
                termdictPage[term][page_id].append(position) 
            except:
                # Add the new term as dict key and initialize the array of positions and add the position
                termdictPage[term]=[page_id, array('I',[position])] #'I' indicates unsigned int (int in python)
        
        #normalize term frequencies
        # Compute the denominator to normalize term frequencies (formula 2 above)
        # norm is the same for all terms of a document.
        norm=0
        for term, posting in termdictPage.items(): 
            # posting is a list containing doc_id and the list of positions for current term in current document: 
            # posting ==> [currentdoc, [list of positions]] 
            # you can use it to inferr the frequency of current term.
            norm+=len(posting[1])**2
        norm=math.sqrt(norm)


        #calculate the tf(dividing the term frequency by the above computed norm) and df weights
        for term, posting in termdictPage.items():     
            # append the tf for current term (tf = term frequency in current doc/norm)
            tf[term].append(np.round(len(posting[1])/norm,4))  ## SEE formula (1) above
            #increment the document frequency of current term (number of documents containing the current term)
            df[term]= df[term] + 1  # increment df for current term
        
        #merge the current page index with the main index
        for termpage, postingpage in termdictPage.items():
            index[termpage].append(postingpage)
            
    # Compute idf following the formula (3) above. HINT: use np.log
    for term in df:
        idf[term] = np.round(np.log(float(len(termdictPage.items())/df[term])),4)

    return index, tf, df, idf

# %%
def rankDocuments(terms, docs, index, idf, tf):
    """
    Perform the ranking of the results of a search based on the tf-idf weights
    
    Argument:
    terms -- list of query terms
    docs -- list of documents, to rank, matching the query
    index -- inverted index data structure
    idf -- inverted document frequencies
    tf -- term frequencies
    titleIndex -- mapping between page id and page title
    
    Returns:
    Print the list of ranked documents
    """
    global data
    
    T=1
    # I'm interested only on the element of the docVector corresponding to the query terms 
    # The remaing elements would became 0 when multiplied to the queryVector
    docVectors=defaultdict(lambda: [0]*len(terms)) # I call docVectors[k] for a nonexistent key k, the key-value pair (k,[0]*len(terms)) will be automatically added to the dictionary
    queryVector=[0]*len(terms)    

    # compute the norm for the query tf
    query_terms_count = collections.Counter(terms) # get the frequency of each term in the query. 
    # Example: collections.Counter(["hello","hello","world"]) --> Counter({'hello': 2, 'world': 1})
    # HINT: use when computing tf for queryVector
    
    query_norm = la.norm(list(query_terms_count.values()))
    
    for termIndex, term in enumerate(terms): #termIndex is the index of the term in the query
        if term not in index:
            continue
                    
        ## Compute tf*idf(normalize tf as done with documents)
        queryVector[termIndex]= query_terms_count[term]/query_norm * idf[term]

        # Generate docVectors for matching docs
        for docIndex, (doc, postings) in enumerate(index[term]):
            # Example of [docIndex, (doc, postings)]
            # 0 (26, array('I', [1, 4, 12, 15, 22, 28, 32, 43, 51, 68, 333, 337]))
            # 1 (33, array('I', [26, 33, 57, 71, 87, 104, 109]))
            # term is in doc 26 in positions 1,4, .....
            # term is in doc 33 in positions 26,33, .....
            
            #tf[term][0] will contain the tf of the term "term" in the doc 26            
            if doc in docs:
                docVectors[doc][termIndex]=tf[term][docIndex] * idf[term]  # TODO: check if multiply for idf
                
    # calculate the score of each doc
    # compute the cosine similarity between queyVector and each docVector:
    # HINT: you can use the dot product because in case of normalized vectors it corresponds to the cosine siilarity
    # see np.dot

    #The  TF-IDF + cosine similarity scoring
    docScores=[ [np.dot(curDocVec, queryVector), doc] for doc, curDocVec in docVectors.items() ]
    docScores.sort(reverse=True)
    resultDocs=[x[1] for x in docScores]
    #print document titles instead if document id's
    
    if len(resultDocs) == 0:
        print("No results found, try again")
        query = input()
        docs = search_tf_idf(query, index)    
    #print ('\n'.join(resultDocs), '\n')
    return docScores

# %%
def search_tf_idf(query, index):
    '''
    output is the list of documents that contain any of the query terms. 
    So, we will get the list of documents for each query term, and take the union of them.
    '''
    query=getTerms_str(query)
    
    init_docs = [posting[0] for posting in index[query[0]]]
    docs = set(init_docs)
    
    for term in query[1:]:
        try:
            # store in termDocs the ids of the docs that contain "term"                        
            termDocs=[posting[0] for posting in index[term]]
            
            # docs = docs Union termDocs
            docs = docs.intersection(set(termDocs))
        except:
            #term is not in index
            pass
    docs=list(docs)
    ranked_docs = rankDocuments(query, docs, index, idf, tf)   
    return ranked_docs

# %%
def print_tweet(tweet, n, score):
    '''
    Print information about tweet n from the ranking in a organized format.
    
    Argument:
    tweet -- information to print
    n -- number of tweet in the ranking
    '''
    print('\nResult {} (score {:.5})'.format(n,score))
    print("-"*70)
    print(tweet.text)
    if isinstance(tweet.hashtags,str):
        print(f'\nHashtags: {tweet.hashtags}')
    print(f'\nTweet by user {tweet.user_screen_name}')
    print(f'\t❤️ {tweet.favorite_count}\t🔁 {tweet.retweet_count}\t📅{tweet.created_at}')
    print(f'Url: {tweet.url}\n')
    print("="*70)

# %%
from IPython.display import display
def search_engine(data, index, tsv=False):
    query = input("Search: ")
    result = search_tf_idf(query, index)
    
    #first score, next id
    scoresx= [x[0] for x in result]
    positionx= [x[1] for x in result]
    tweets = data[data['tweet_id'].isin(positionx)].set_index('tweet_id')
    
    to_return = pd.DataFrame()
    vars_to_return = ['text','user_screen_name','created_at','hashtags','favorite_count','retweet_count','url']
    
    print("="*70)
    for i in range(0,min(20,len(tweets)),1):
        tweet = tweets.loc[positionx[i]]
        print_tweet(tweet, i+1, scoresx[i])
        if tsv == True:
            to_append = tweet.loc[vars_to_return]
            to_return = to_return.append(to_append,ignore_index=True)
    
    if tsv == True:
        name = str('ranking_'+query+'_basic.tsv')
        to_return.to_csv(name, sep = '\t', quotechar='"')

# %%
data.head()
# Out:
#    tweet_id                                               text  \
# 0         1  The polls are absolutely wrong! All you have t...
# 1         8   _Lai And the dangerous part? When there is pu...
# 2        19  News flash. tRump IS a politician. https://t.c...
# 3        35  #NewYorkPost published a report saying e-mails...
# 4        39   @realDonaldTrump    @JoeBiden GOP HAS APPOINT...
#
#                    user_screen_name                      created_at  \
# 0  590ecf4c5b88c57f5658f3097f32efd2  Tue Oct 20 15:11:08 +0000 2020
# 1  203afe8023cab3bb1fa15ec48c737a71  Tue Oct 20 15:10:48 +0000 2020
# 2  a708a5aef0063b7a40cd2bbbf51984c0  Tue Oct 20 15:10:10 +0000 2020
# 3  c1170c45d30c5a1c258ba52e5e8349f6  Tue Oct 20 15:09:31 +0000 2020
# 4  2d9df2e6b9ecba9c119fc674c211b5ec  Tue Oct 20 15:09:14 +0000 2020
#
#    favorite_count  retweet_count  user_followers  \
# 0               0              0               3
# 1              18              1            2502
# 2               1              0             275
# 3               1              1             106
# 4               0              0             197
#
#                                                  url  user_followers_index  \
# 0  https://twitter.com/twitter/statuses/131857045...              0.832457
# 1  https://twitter.com/twitter/statuses/131857037...              0.915293
# 2  https://twitter.com/twitter/statuses/131857020...              0.845215
# 3  https://twitter.com/twitter/statuses/131857004...              0.837466
# 4  https://twitter.com/twitter/statuses/131856997...              0.841707
#
#                                             hashtags  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  NewYorkPost, JoeBiden, HunterBiden, BREAKING, ...
# 4                                                NaN
#
#                                                words
# 0  [poll, absolut, wrong, watch, ralli, see, incr...
# 1  [lai, danger, part, pushback, dont, say, anyth...
# 2                   [news, flash, trump, politician]
# 3  [newyorkpost, publish, report, say, email, obt...
# 4  [realdonaldtrump, joebiden, gop, appoint, 14, ...

# %% [markdown]
# # Creating the index and searching

# %%
start=time.time()
getTerms()
print(time.time()-start)
data['text'].head()
# Out:
# 5.037353992462158
# 0    The polls are absolutely wrong! All you have t...
# 1     _Lai And the dangerous part? When there is pu...
# 2    News flash. tRump IS a politician. https://t.c...
# 3    #NewYorkPost published a report saying e-mails...
# 4     @realDonaldTrump    @JoeBiden GOP HAS APPOINT...
# Name: text, dtype: object

# %%
start=time.time()
index, tf, df, idf = create_index_tfidf()
print(time.time()-start)
# Out:
# 4.181371212005615

# %%
search_engine(data, index, tsv=True)
# Out:
# Search: fake news
# ======================================================================
#
# Result 1 (score 3.2778)
# ----------------------------------------------------------------------
#   FAKE NEWS !!!!!!THESE POLLS ARE A FUCKING JOKE JUST LIKE BIDEN
#
# Tweet by user d7d71e778a61ce2ddd6beb7b14b722a0
# 	❤️ 0	🔁 0	📅Tue Oct 13 15:51:41 +0000 2020
# Url: https://twitter.com/twitter/statuses/1316043940878053378
#
# ======================================================================
#
# Result 2 (score 3.2778)
# ----------------------------------------------------------------------
# No wonder Donald Trump thinks everything is fake news.
#
# Tweet by user 335baa3e561d423665e968274947e6ed
# 	❤️ 0	🔁 0	📅Fri Oct 16 13:06:42 +0000 2020
# Url: https://twitter.com/twitter/statuses/1317089587882192897
#
# ======================================================================
#
# Result 3 (score 3.0662)
# ----------------------------------------------------------------------
#   You obviously have been watching fake news instead of paying attention.Trump 2020
#
# Tweet by user 055c35e7c04ac59e87c39f7551380d56
# 	❤️ 1	🔁 0	📅Wed Oct 14 16:34:26 +0000 2020
# Url: https://twitter.com/twitter/statuses/1316417089868124160
#
# ======================================================================
#
# Result 4 (score 2.8902)
# ----------------------------------------------------------------------
# So glad you said this so many will believe you and nit the FAKE NEWS!! Trump 2020 https://t.co/BrNFKiGhfs
#
# Tweet by user 1d7aa265e2e0c614b5157482fddce68f
# 	❤️ 1	🔁 0	📅Fri Oct 16 00:48:25 +0000 2020
# Url: https://twitter.com/twitter/statuses/1316903793439723524
#
# ======================================================================
#
# Result 5 (score 2.7419)
# ----------------------------------------------------------------------
#  Trump is so confident he can walkinto a fake news trap and escapetheir snare un scathed
#
# Tweet by user 39449a5e829877df62dfd8e9e9793072
# 	❤️ 1	🔁 0	📅Fri Oct 16 01:42:51 +0000 2020
# Url: https://twitter.com/twitter/statuses/1316917489826205701
#
# ======================================================================
#
# Result 6 (score 2.7419)
# ----------------------------------------------------------------------
#    Fake News! Oh yeah Biden’s have a lot to answer for! Things are just getting started with the Biden’s!
#
# Tweet by user 9eb4cc9fac9ef4119cf700d6eddc8205
# 	❤️ 4	🔁 0	📅Thu Oct 15 17:56:56 +0000 2020
# Url: https://twitter.com/twitter/statuses/1316800237609062400
#
# ======================================================================
#
# Result 7 (score 2.7419)
# ----------------------------------------------------------------------
#  You make it seem that Fauci said Trump is undermining him but he didn’t say that . More fake news!
#
# Tweet by user 4f032c1f4752d8974259eabdfe15fe35
# 	❤️ 0	🔁 0	📅Tue Oct 13 18:31:48 +0000 2020
# Url: https://twitter.com/twitter/statuses/1316084239373348867
#
# ======================================================================
#
# Result 8 (score 2.7419)
# ----------------------------------------------------------------------
# Trump: “we will ALWAYS protect people with preexisting conditions”Stop listening to the fake news. #TrumpTownHall
#
# Hashtags: TrumpTownHall
#
# Tweet by user 67cdddae7cfc010d91dc202a58fbba3d
# 	❤️ 38	🔁 13	📅Fri Oct 16 00:35:28 +0000 2020
# Url: https://twitter.com/twitter/statuses/1316900532808724480
#
# ======================================================================
#
# Result 9 (score 2.6144)
# ----------------------------------------------------------------------
# Here's A Great Video on Trump Derangement Syndrome! Concerning folks who have been Brainwashed by fake news... https://t.co/UdplYjA52u
#
# Tweet by user 11596adc55137c3c91e60061f33642c8
# 	❤️ 0	🔁 0	📅Tue Oct 13 15:58:29 +0000 2020
# Url: https://twitter.com/twitter/statuses/1316045653466898436
#
# ======================================================================
#
# Result 10 (score 2.6144)
# ----------------------------------------------------------------------
#  Why is NBC holding this event for Trump? All he does is trash NBC and MSNBC and call every report FAKE news.
#
# Tweet by user ab1e0956ff44ff4a64fa8bffc161b02f
# 	❤️ 2	🔁 0	📅Wed Oct 14 17:20:49 +0000 2020
# Url: https://twitter.com/twitter/statuses/1316428762532270081
#
# ======================================================================
#
# Result 11 (score 2.6144)
# ----------------------------------------------------------------------
#  The story stinks and is full of holes. This is obviously a fake news setup. Just a sign of the desperation Trump is in
#
# Tweet by user c93a902151cf29fe6b24fab7433325ca
# 	❤️ 1	🔁 0	📅Wed Oct 14 15:43:39 +0000 2020
# Url: https://twitter.com/twitter/statuses/1316404308418523137
#
# ======================================================================
#
# Result 12 (score 2.6144)
# ----------------------------------------------------------------------
# Trump: what can I do for u my king how can I serve u what can I do for u my kingFossi: trump is lying to u allTrump: ur an idiot fake news
#
# Tweet by user 5db8b950afe6e6dfb8dc3929e5c2bd58
# 	❤️ 0	🔁 1	📅Tue Oct 20 16:51:53 +0000 2020
# Url: https://twitter.com/twitter/statuses/1318595808909008896
#
# ======================================================================
#
# Result 13 (score 2.6144)
# ----------------------------------------------------------------------
# They really are desperate because Trump and his Crime Family are losing they will attack the Bidens and spread Fake News https://t.co/GnumMuARBX
#
# Tweet by user 13284ec8e7a3deb082934e815a6f7fb3
# 	❤️ 0	🔁 0	📅Sun Oct 18 20:13:49 +0000 2020
# Url: https://twitter.com/twitter/statuses/1317921849276305408
#
# ======================================================================
#
# Result 14 (score 2.4054)
# ----------------------------------------------------------------------
# Dick Morris on Newsmax explained how the fake news polls try to manipulate Trump voters not to bother. Evil.
#
# Tweet by user 1ce4b27c0ef5f4be9584a7268dc035c3
# 	❤️ 2	🔁 3	📅Wed Oct 14 03:24:06 +0000 2020
# Url: https://twitter.com/twitter/statuses/1316218195707977730
#
# ======================================================================
#
# Result 15 (score 2.4054)
# ----------------------------------------------------------------------
# Is Biden taking dementia medication? Think this is something Americans should know? Shame on Jill Biden! And defund fake news!!
#
# Tweet by user 8c13db7f762a524c5304ab307c7f8830
# 	❤️ 0	🔁 0	📅Tue Oct 13 17:57:59 +0000 2020
# Url: https://twitter.com/twitter/statuses/1316075729080254469
#
# ======================================================================
#
# Result 16 (score 2.4054)
# ----------------------------------------------------------------------
# Kamala is interviewing Judge Barrett right now... live on TV. No fake news. Tune in and see what you think. No spin... it’s live!
#
# Tweet by user fb041b2c2b5ceca5d86f8cc2b7b9eb56
# 	❤️ 0	🔁 0	📅Tue Oct 13 23:23:00 +0000 2020
# Url: https://twitter.com/twitter/statuses/1316157518964457474
#
# ======================================================================
#
# Result 17 (score 2.4054)
# ----------------------------------------------------------------------
#      @JoeBiden Nor do you on the Biden’s...this laptop is it?  Why didn’t the FBI do anything about it?...q your conspiracy response fbi’s corrupt fake news etc
#
# Tweet by user 07f3cf6cfaf1682b183d2bd45f34e1c4
# 	❤️ 2	🔁 0	📅Fri Oct 16 19:04:25 +0000 2020
# Url: https://twitter.com/twitter/statuses/1317179610807848960
#
# ======================================================================
#
# Result 18 (score 2.4054)
# ----------------------------------------------------------------------
# Twitter! Please flag this tweet! It’s fake news! There’s clearly a typo. He clearly meant to say Republican Party* 😌 https://t.co/x8mWkYhGyi
#
# Tweet by user 48a8f10b57e5cfe7011265f27ab7c80a
# 	❤️ 0	🔁 0	📅Mon Oct 19 14:51:56 +0000 2020
# Url: https://twitter.com/twitter/statuses/1318203233807048704
#
# ======================================================================
#
# Result 19 (score 2.3179)
# ----------------------------------------------------------------------
# Trump calling himself “Big T” now. Actually that’s fake news. According to Stormy Daniels Trump has a tiny mushroom shaped d**k. 🍄 https://t.co/U0ZxOEYBX8
#
# Tweet by user e0dbd01d93c6496e375da09d6ff4d8fd
# 	❤️ 0	🔁 0	📅Fri Oct 16 12:18:04 +0000 2020
# Url: https://twitter.com/twitter/statuses/1317077346189340673
#
# ======================================================================
#
# Result 20 (score 2.239)
# ----------------------------------------------------------------------
# The fact that Trump is tweet literal fake new from the Babylon bee which is a news satire site to try and have a “gotcha” moment is hilarious
#
# Tweet by user 4a5c00a769557cc0584b7cf8fec93585
# 	❤️ 0	🔁 0	📅Fri Oct 16 17:26:53 +0000 2020
# Url: https://twitter.com/twitter/statuses/1317155062724972544
#
# ======================================================================

# %% [markdown]
# # Research Questions
#
# # 1stRQ - Output Analysis

# %%
data.head()
# Out:
#    tweet_id                                               text  \
# 0         1  The polls are absolutely wrong! All you have t...
# 1         8   _Lai And the dangerous part? When there is pu...
# 2        19  News flash. tRump IS a politician. https://t.c...
# 3        35  #NewYorkPost published a report saying e-mails...
# 4        39   @realDonaldTrump    @JoeBiden GOP HAS APPOINT...
#
#                    user_screen_name                      created_at  \
# 0  590ecf4c5b88c57f5658f3097f32efd2  Tue Oct 20 15:11:08 +0000 2020
# 1  203afe8023cab3bb1fa15ec48c737a71  Tue Oct 20 15:10:48 +0000 2020
# 2  a708a5aef0063b7a40cd2bbbf51984c0  Tue Oct 20 15:10:10 +0000 2020
# 3  c1170c45d30c5a1c258ba52e5e8349f6  Tue Oct 20 15:09:31 +0000 2020
# 4  2d9df2e6b9ecba9c119fc674c211b5ec  Tue Oct 20 15:09:14 +0000 2020
#
#    favorite_count  retweet_count  user_followers  \
# 0               0              0               3
# 1              18              1            2502
# 2               1              0             275
# 3               1              1             106
# 4               0              0             197
#
#                                                  url  user_followers_index  \
# 0  https://twitter.com/twitter/statuses/131857045...              0.832457
# 1  https://twitter.com/twitter/statuses/131857037...              0.915293
# 2  https://twitter.com/twitter/statuses/131857020...              0.845215
# 3  https://twitter.com/twitter/statuses/131857004...              0.837466
# 4  https://twitter.com/twitter/statuses/131856997...              0.841707
#
#                                             hashtags  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  NewYorkPost, JoeBiden, HunterBiden, BREAKING, ...
# 4                                                NaN
#
#                                                words
# 0  [poll, absolut, wrong, watch, ralli, see, incr...
# 1  [lai, danger, part, pushback, dont, say, anyth...
# 2                   [news, flash, trump, politician]
# 3  [newyorkpost, publish, report, say, email, obt...
# 4  [realdonaldtrump, joebiden, gop, appoint, 14, ...

# %%
data.shape
# Out:
# (15000, 11)

# %%
data[data['tweet_id']==1].words.to_list()[0]
# Out:
# ['poll',
#  'absolut',
#  'wrong',
#  'watch',
#  'ralli',
#  'see',
#  'incred',
#  'amount',
#  'peopl',
#  'attend',
#  'look',
#  'like',
#  'ralli',
#  'keep',
#  'get',
#  'bigger',
#  'amp',
#  'bigger',
#  'vote',
#  'trump']

# %%
#!pip install gensim

# %% [markdown]
# ## Words embedding work
#
# With the next cells we transform each given word in our tweets to a vector representation in 300 dimensions.

# %%
import gensim.models


words_per_tweet = data.words.to_list()
training_words = [item for sublist in words_per_tweet for item in sublist]

# min_count = 1, doing so all words are vectorized

model = gensim.models.Word2Vec(words_per_tweet,min_count=1,size=300)
#model.build_vocab(training_words)
#model.train(training_words,total_examples=len(training_words),epochs=30)

# %%
# see some arithmetics
model[training_words[0]] + model[training_words[1]] + np.zeros(300)
# Out:
# array([-7.98969865e-01,  7.89538503e-01, -4.92297351e-01,  2.78140187e-01,
#        -1.37025690e+00,  2.02175677e-01,  3.09108019e-01, -8.31256509e-02,
#         3.34440619e-01,  3.91935170e-01,  1.08369899e+00, -8.62856507e-01,
#         4.67587858e-01, -9.34853684e-04,  5.30435704e-02,  7.65269518e-01,
#         1.40402317e-01, -3.72056812e-01,  8.90508220e-02,  4.84161675e-01,
#         6.53337657e-01,  6.60670042e-01, -1.69343203e-01, -9.92153212e-02,
#        -1.38165548e-01, -5.68809500e-03,  7.50484914e-02, -6.15621865e-01,
#         5.82023501e-01,  5.78902125e-01, -8.86625826e-01, -4.30098683e-01,
#         2.00566381e-01, -2.47525066e-01,  2.78121889e-01, -5.28961360e-01,
#         9.61021781e-02,  6.45843968e-02,  1.34026432e+00,  3.75483483e-01,
#         3.05615664e-01, -3.97935152e-01, -3.47572923e-01, -6.76973581e-01,
#         6.01708114e-01,  1.18725526e+00, -1.34257481e-01,  8.91543269e-01,
#         3.64259958e-01,  2.97901362e-01, -6.54979825e-01,  6.60503507e-01,
#         3.80385458e-01,  7.79163003e-01, -2.97814727e-01,  1.75645143e-01,
#        -5.67216933e-01,  1.99768662e-01,  2.48853832e-01, -6.21470273e-01,
#         4.04113233e-01,  1.15238294e-01, -6.63210154e-01, -2.10346878e-01,
#        -7.05413938e-01,  3.51037323e-01,  1.00213897e+00,  3.05874854e-01,
#         8.61548424e-01, -5.33561587e-01, -9.54762101e-02,  4.11637798e-02,
#         3.20462167e-01,  8.52341890e-01, -2.87888199e-01,  5.43825090e-01,
#        -6.06097043e-01,  7.00612903e-01, -3.68593708e-02,  1.66509360e-01,
#        -4.19666469e-01, -1.13258588e+00, -1.49505481e-01, -6.80225313e-01,
#         1.22165394e+00,  1.35387838e-01,  2.57736538e-04, -9.20554399e-02,
#         5.45218945e-01, -1.75132900e-01,  2.64631212e-01, -5.13156414e-01,
#        -8.86508703e-01, -1.03501163e-01,  4.00156438e-01, -8.94933790e-02,
#         5.63668609e-01, -2.96364635e-01, -6.58570409e-01,  7.58739710e-01,
#        -2.20523328e-01,  6.00099742e-01, -3.11737359e-01, -1.06538221e-01,
#        -2.67585486e-01, -1.00581026e+00,  9.12615538e-01,  1.63328439e-01,
#         9.01292205e-01, -1.19873017e-01, -2.98435032e-01,  1.87285393e-01,
#         6.20494224e-02,  2.52854168e-01, -2.37975255e-01,  2.68638343e-01,
#        -4.79415119e-01, -1.11825749e-01,  9.71250385e-02,  5.26208103e-01,
#        -7.12505579e-01,  2.84379095e-01, -4.31756914e-01, -1.86476141e-01,
#         5.18399477e-01, -4.37969267e-01,  3.51441622e-01, -5.72337449e-01,
#         3.32082272e-01, -1.18670195e-01,  2.66854227e-01,  1.14003026e+00,
#        -1.32704958e-01, -2.91681588e-01, -1.37345597e-01,  1.08037841e+00,
#        -3.02685529e-01, -6.04409933e-01, -6.09965205e-01,  7.71033645e-01,
#        -6.61956787e-01,  1.23125300e-01, -2.98845861e-02,  9.57278728e-01,
#        -6.16109490e-01,  1.23339191e-01, -1.17409849e+00,  4.89760995e-01,
#         5.01202106e-01, -6.38912469e-02, -2.55924761e-01,  3.92900288e-01,
#        -2.56208003e-01,  6.38196915e-02, -5.64837575e-01,  4.41760540e-01,
#        -1.03832215e-01,  1.38241976e-01,  1.33252949e-01, -1.66711539e-01,
#        -3.86870027e-01, -8.72660875e-01, -5.87078869e-01, -4.95023787e-01,
#         6.36634052e-01,  2.61241160e-02, -5.14609143e-02, -4.32160646e-02,
#         4.16789591e-01,  9.65288281e-01, -7.56253719e-01, -3.19483802e-02,
#         8.11845005e-01, -7.96295032e-02, -2.73412894e-02, -1.98219091e-01,
#         8.51894855e-01, -4.75722432e-01,  3.81135672e-01, -2.58662075e-01,
#        -1.31298766e-01, -7.15340734e-01, -3.94214392e-01,  2.17691854e-01,
#         5.00532448e-01,  1.67960562e-02,  2.87102580e-01, -6.28632069e-01,
#         1.92994237e-01, -5.63274682e-01, -4.01976943e-01, -8.31509650e-01,
#         4.43719506e-01, -2.93442845e-01,  1.36878863e-01,  1.53258353e-01,
#        -4.98580813e-01, -6.40348911e-01, -3.96326244e-01,  6.55838996e-02,
#         3.32454205e-01,  1.56883657e-01,  4.24708486e-01,  2.19314516e-01,
#        -7.52013028e-02, -9.36646760e-01,  9.89692628e-01,  2.05682546e-01,
#        -4.62181747e-01,  1.19963907e-01,  3.73027325e-01,  2.91485906e-01,
#        -2.35177185e-02,  7.02972189e-02, -1.51471347e-01, -1.22136962e+00,
#         1.78032622e-01,  2.66268730e-01,  3.16517949e-01, -5.59945069e-02,
#        -2.05050677e-01, -2.24726163e-02, -4.82212305e-01, -4.17732716e-01,
#         5.39828777e-01,  7.27493882e-01, -3.39353025e-01,  3.39310378e-01,
#        -3.37940544e-01,  5.27813315e-01,  3.21767569e-01, -3.94431889e-01,
#        -3.82954508e-01,  2.40406528e-01,  2.96974719e-01,  2.43648067e-01,
#        -1.07243848e+00,  8.81376863e-03, -2.77971812e-02,  5.92157662e-01,
#         3.13253999e-01,  3.14506590e-01, -7.35441566e-01,  1.33484691e-01,
#         1.09905437e-01,  1.00937098e-01,  5.99346638e-01, -1.48754632e-02,
#         4.85303923e-02,  3.87476236e-01, -4.57384646e-01, -2.10173383e-01,
#        -3.82270187e-01,  9.79305148e-01,  3.98286402e-01, -1.22514319e+00,
#        -1.09099552e-01,  4.11580563e-01,  1.18809402e-01,  8.19577486e-04,
#        -5.58431387e-01,  1.02744794e+00,  8.00276697e-02,  9.30946529e-01,
#         1.12848446e-01, -1.46990651e-02, -2.56557375e-01, -9.86283779e-01,
#        -1.11082010e-01, -7.16921091e-01, -3.32238495e-01,  7.14476883e-01,
#         3.25398088e-01,  1.67283535e-01, -6.40679896e-02,  4.90467042e-01,
#        -4.56003606e-01, -1.02420044e+00, -7.95619786e-02, -3.61852944e-01,
#         3.89337242e-01, -7.17191994e-01, -1.07258046e+00,  1.00054109e+00,
#        -2.46408403e-01, -7.24562258e-02, -4.05325681e-01,  1.81885615e-01,
#         1.09633483e-01,  7.21713424e-01,  3.32206517e-01,  3.89789492e-01,
#         2.96895921e-01,  3.21685970e-01, -7.51029372e-01,  5.11281133e-01,
#        -1.47258019e+00, -6.18782118e-02, -1.32931185e+00, -7.78568387e-01])

# %%
vocabulary = model.wv.vocab.keys()
training_words[0] in vocabulary
# Out:
# True

# %% [markdown]
# The next cell should not print nothing at all, because it means that all possible words are in the embedding space.

# %%
for word in training_words:
    if word not in vocabulary:
        print(word)

# %% [markdown]
# # Searching and ranking in word2vec + cosine similarity implementation
#
# As says in project 1stRQ requirements, we compute sentences as averaged combinations of word vectors in the embedded space. So, query and tweet messages are first computed as averaged combinations of their own words in the N dimensional space (300), and then similarity score between query and document is computed as the cosine similarity, i.e the dot product of both normalized vectors.

# %%
def word2vec_ranking(model,query,tweet_id_list,data):
    
    from numpy import linalg as LA
    import numpy as np
    
    # computes cosine similarities from embedded word vectors
    
    cosine_dict = {} # query-doc similarity
    ranked_tweets = []
    
    # query average embedding
    u = np.zeros(300)
    for i in range(len(query)):
        u = u + model[query[i]]
    u = u*(1/len(query))
    
    for tweet_id in tweet_id_list:
        
        tweet_words = data[data['tweet_id']==tweet_id].words.to_list()[0]
        
        # tweet text average embedding
        v = np.zeros(300)
        for i in range(len(tweet_words)):
            v = v + model[tweet_words[i]]
        v = v*(1/len(tweet_words))
    
        cosine_dict[tweet_id] = np.dot(u,v)/(LA.norm(u)*LA.norm(v))
    
    sorted_similarities=sorted(cosine_dict.items(), key=lambda dist: dist[1],reverse = True) ## in Descedning order
    
    for item in sorted_similarities:
        ranked_tweets.append(list([item[0],item[1]]))
    
    # returns tweet ids
    return ranked_tweets

# %%
def search_word2vec(query, index, model, data):
    '''
    output is the list of documents that contain any of the query terms. 
    So, we will get the list of documents for each query term, and take the union of them.
    '''
    query=getTerms_str(query)
    
    init_docs = [posting[0] for posting in index[query[0]]]
    docs = set(init_docs)
    
    for term in query[1:]:
        try:
                                  
            termDocs=[posting[0] for posting in index[term]]
            
            docs = docs.intersection(set(termDocs))
        except:
            #term is not in index
            pass
        
   
    docs=list(docs) # lista de tweet ids
    
    ranked_docs = word2vec_ranking(model,query,docs,data)
    return ranked_docs

# %%
def search_engine_word2vec(model, data, index, tsv=False):
    query = input("Search: ")
    result = search_word2vec(query, index, model, data)
    positionx= [x[0] for x in result]
    scoresx= [x[1] for x in result]
    tweets = data[data['tweet_id'].isin(positionx)].set_index('tweet_id')
    
    to_return = pd.DataFrame()
    vars_to_return = ['text','user_screen_name','created_at','hashtags','favorite_count','retweet_count','url']
    
    print("="*70)
    for i in range(0,min(20,len(tweets)),1):
        tweet = tweets.loc[positionx[i]]
        print_tweet(tweet, i+1, scoresx[i])
        
        if tsv == True:
            to_append = tweet.loc[vars_to_return]
            to_return = to_return.append(to_append,ignore_index=True)
    
    if tsv == True:
        name = str('ranking_'+query+'_word2vec.tsv')
        to_return.to_csv(name, sep = '\t', quotechar='"')

# %%
search_engine_word2vec(model, data, index, tsv=True)
# Out:
# Search: fake news
# ======================================================================
#
# Result 1 (score 0.99907)
# ----------------------------------------------------------------------
#  Why is NBC holding this event for Trump? All he does is trash NBC and MSNBC and call every report FAKE news.
#
# Tweet by user ab1e0956ff44ff4a64fa8bffc161b02f
# 	❤️ 2	🔁 0	📅Wed Oct 14 17:20:49 +0000 2020
# Url: https://twitter.com/twitter/statuses/1316428762532270081
#
# ======================================================================
#
# Result 2 (score 0.99821)
# ----------------------------------------------------------------------
#  Exactly right. This was supposed to be a town hall Not a debate between President Trump and the fake news biased commentator. . I guess we should expect that. Very Sad. Trump does great when he gets to talk directly to people
#
# Tweet by user a58536ec8388d4a35add1c3bc61ea96e
# 	❤️ 1	🔁 0	📅Fri Oct 16 01:24:20 +0000 2020
# Url: https://twitter.com/twitter/statuses/1316912830197747714
#
# ======================================================================
#
# Result 3 (score 0.9981)
# ----------------------------------------------------------------------
#   You obviously have been watching fake news instead of paying attention.Trump 2020
#
# Tweet by user 055c35e7c04ac59e87c39f7551380d56
# 	❤️ 1	🔁 0	📅Wed Oct 14 16:34:26 +0000 2020
# Url: https://twitter.com/twitter/statuses/1316417089868124160
#
# ======================================================================
#
# Result 4 (score 0.99678)
# ----------------------------------------------------------------------
#   FAKE NEWS !!!!!!THESE POLLS ARE A FUCKING JOKE JUST LIKE BIDEN
#
# Tweet by user d7d71e778a61ce2ddd6beb7b14b722a0
# 	❤️ 0	🔁 0	📅Tue Oct 13 15:51:41 +0000 2020
# Url: https://twitter.com/twitter/statuses/1316043940878053378
#
# ======================================================================
#
# Result 5 (score 0.99639)
# ----------------------------------------------------------------------
#  Trump is so confident he can walkinto a fake news trap and escapetheir snare un scathed
#
# Tweet by user 39449a5e829877df62dfd8e9e9793072
# 	❤️ 1	🔁 0	📅Fri Oct 16 01:42:51 +0000 2020
# Url: https://twitter.com/twitter/statuses/1316917489826205701
#
# ======================================================================
#
# Result 6 (score 0.99621)
# ----------------------------------------------------------------------
#  I'll be watching ABC Joe Biden. Why didn't FOXNews host the jackass townhall. I thought CNN MSNBC ABC etc were fake news oh he is desperate he needs all the fake news to host along with the fake people to watch.
#
# Tweet by user caecf1fdda98dd10e47f29aa20480561
# 	❤️ 0	🔁 0	📅Wed Oct 14 14:36:31 +0000 2020
# Url: https://twitter.com/twitter/statuses/1316387413208506368
#
# ======================================================================
#
# Result 7 (score 0.9962)
# ----------------------------------------------------------------------
# So     Refuse to run actual news on hunter biden and the shady dealing him and his father were involved in but yet anything remotely negative and mostly fake stuff put out on trump gets front page news. Unreal this media bias.
#
# Tweet by user d60ee75e4e8a7965943ea16c8d07b865
# 	❤️ 0	🔁 0	📅Fri Oct 16 01:06:07 +0000 2020
# Url: https://twitter.com/twitter/statuses/1316908247916433412
#
# ======================================================================
#
# Result 8 (score 0.99603)
# ----------------------------------------------------------------------
# They really are desperate because Trump and his Crime Family are losing they will attack the Bidens and spread Fake News https://t.co/GnumMuARBX
#
# Tweet by user 13284ec8e7a3deb082934e815a6f7fb3
# 	❤️ 0	🔁 0	📅Sun Oct 18 20:13:49 +0000 2020
# Url: https://twitter.com/twitter/statuses/1317921849276305408
#
# ======================================================================
#
# Result 9 (score 0.99593)
# ----------------------------------------------------------------------
#  The story stinks and is full of holes. This is obviously a fake news setup. Just a sign of the desperation Trump is in
#
# Tweet by user c93a902151cf29fe6b24fab7433325ca
# 	❤️ 1	🔁 0	📅Wed Oct 14 15:43:39 +0000 2020
# Url: https://twitter.com/twitter/statuses/1316404308418523137
#
# ======================================================================
#
# Result 10 (score 0.99569)
# ----------------------------------------------------------------------
#    Fake News! Oh yeah Biden’s have a lot to answer for! Things are just getting started with the Biden’s!
#
# Tweet by user 9eb4cc9fac9ef4119cf700d6eddc8205
# 	❤️ 4	🔁 0	📅Thu Oct 15 17:56:56 +0000 2020
# Url: https://twitter.com/twitter/statuses/1316800237609062400
#
# ======================================================================
#
# Result 11 (score 0.99556)
# ----------------------------------------------------------------------
# Is Biden taking dementia medication? Think this is something Americans should know? Shame on Jill Biden! And defund fake news!!
#
# Tweet by user 8c13db7f762a524c5304ab307c7f8830
# 	❤️ 0	🔁 0	📅Tue Oct 13 17:57:59 +0000 2020
# Url: https://twitter.com/twitter/statuses/1316075729080254469
#
# ======================================================================
#
# Result 12 (score 0.99523)
# ----------------------------------------------------------------------
# @realDonaldTrump Don't watch Fox news. It's fake news!!  n . I challenge u turn off fox turn on the real news n see what nightmare we're in under Trump. We're in a crisis n I think most AMERiCA knows it
#
# Tweet by user 4bac803c21ce8f211bcedc65aff768e5
# 	❤️ 0	🔁 0	📅Wed Oct 14 23:50:19 +0000 2020
# Url: https://twitter.com/twitter/statuses/1316526783127224320
#
# ======================================================================
#
# Result 13 (score 0.99496)
# ----------------------------------------------------------------------
#      @JoeBiden Nor do you on the Biden’s...this laptop is it?  Why didn’t the FBI do anything about it?...q your conspiracy response fbi’s corrupt fake news etc
#
# Tweet by user 07f3cf6cfaf1682b183d2bd45f34e1c4
# 	❤️ 2	🔁 0	📅Fri Oct 16 19:04:25 +0000 2020
# Url: https://twitter.com/twitter/statuses/1317179610807848960
#
# ======================================================================
#
# Result 14 (score 0.99489)
# ----------------------------------------------------------------------
#   @JoeBiden Where’s the Biden crowd ?If Sleepy 💤 Joe is having a Biden Rally there aught to be Biden supporters on hand chanting for him not Four More Years ! Look 👀 like he’s putting money in a empty whole to me ! No way polls could be correct Fake News you are just protecting your Ad $$ https://t.co/C2olxnQSkK
#
# Tweet by user 0f0c3d118260c42c4ece86e2dbc67ebb
# 	❤️ 2	🔁 0	📅Tue Oct 13 14:57:47 +0000 2020
# Url: https://twitter.com/twitter/statuses/1316030376976871425
#
# ======================================================================
#
# Result 15 (score 0.99452)
# ----------------------------------------------------------------------
#    They are called the silent majority and Trump is winning in front of ur noses like a landslide. Watch it. Of course the reason it surprises you is because you wont see it in CNN remember when we have warned you about Fake News? That’s exactly what it means. #Trump2020 😬
#
# Hashtags: Trump2020
#
# Tweet by user c3deb8e749a4abbaf50e398ffcfc95ce
# 	❤️ 2	🔁 0	📅Tue Oct 20 04:05:53 +0000 2020
# Url: https://twitter.com/twitter/statuses/1318403038911004673
#
# ======================================================================
#
# Result 16 (score 0.99437)
# ----------------------------------------------------------------------
# Kamala is interviewing Judge Barrett right now... live on TV. No fake news. Tune in and see what you think. No spin... it’s live!
#
# Tweet by user fb041b2c2b5ceca5d86f8cc2b7b9eb56
# 	❤️ 0	🔁 0	📅Tue Oct 13 23:23:00 +0000 2020
# Url: https://twitter.com/twitter/statuses/1316157518964457474
#
# ======================================================================
#
# Result 17 (score 0.99388)
# ----------------------------------------------------------------------
# Trump calling himself “Big T” now. Actually that’s fake news. According to Stormy Daniels Trump has a tiny mushroom shaped d**k. 🍄 https://t.co/U0ZxOEYBX8
#
# Tweet by user e0dbd01d93c6496e375da09d6ff4d8fd
# 	❤️ 0	🔁 0	📅Fri Oct 16 12:18:04 +0000 2020
# Url: https://twitter.com/twitter/statuses/1317077346189340673
#
# ======================================================================
#
# Result 18 (score 0.99342)
# ----------------------------------------------------------------------
# Joe Biden could stand in the middle of 5th Avenue and shoot someone and I would still vote for him! #HunterBiden story is fake. Steve Bannon and Giuliani are involved. Enough said! The NY Post is a Fox News wannabe!
#
# Hashtags: HunterBiden
#
# Tweet by user c713cb9d138fa5280576c1fe3a0d1a1b
# 	❤️ 28	🔁 8	📅Wed Oct 14 20:04:40 +0000 2020
# Url: https://twitter.com/twitter/statuses/1316469995019268096
#
# ======================================================================
#
# Result 19 (score 0.99327)
# ----------------------------------------------------------------------
# Here's A Great Video on Trump Derangement Syndrome! Concerning folks who have been Brainwashed by fake news... https://t.co/UdplYjA52u
#
# Tweet by user 11596adc55137c3c91e60061f33642c8
# 	❤️ 0	🔁 0	📅Tue Oct 13 15:58:29 +0000 2020
# Url: https://twitter.com/twitter/statuses/1316045653466898436
#
# ======================================================================
#
# Result 20 (score 0.99271)
# ----------------------------------------------------------------------
# So glad you said this so many will believe you and nit the FAKE NEWS!! Trump 2020 https://t.co/BrNFKiGhfs
#
# Tweet by user 1d7aa265e2e0c614b5157482fddce68f
# 	❤️ 1	🔁 0	📅Fri Oct 16 00:48:25 +0000 2020
# Url: https://twitter.com/twitter/statuses/1316903793439723524
#
# ======================================================================

# %% [markdown]
# ## Tweets embedding, projection and clustering

# %%
from sklearn.decomposition import IncrementalPCA    
from sklearn.manifold import TSNE                   
import numpy as np

# %%
def get_vectors(data,model):
    
    vectors = []
    
    tweet_ids = data.tweet_id.values

    for num, row in data.iterrows():

        tweet_words = row.words
        
        
    
        if len(tweet_words)!=0:

            v = np.zeros(300)
            for i in range(len(tweet_words)):
                v = v + model[tweet_words[i]]
            v = v*(1/len(tweet_words))

            vectors.append(v)

    vectors = np.asarray(vectors)
    return vectors

# %%
tweet_vecs = get_vectors(data,model)
tweet_vecs
# Out:
# array([[-0.40646249,  0.41235966, -0.25036324, ..., -0.04092589,
#         -0.68437134, -0.38654495],
#        [-0.34981818,  0.34936103, -0.21423576, ..., -0.02668267,
#         -0.56806681, -0.33303505],
#        [-0.30142235,  0.33031536, -0.19414472, ..., -0.01691451,
#         -0.57607992, -0.30160864],
#        ...,
#        [-0.40364553,  0.37649735, -0.24496497, ..., -0.01810025,
#         -0.64024018, -0.39221785],
#        [-0.29858683,  0.33133935, -0.18648422, ..., -0.05898054,
#         -0.55862968, -0.2947318 ],
#        [-0.28301092,  0.36135964, -0.21133293, ..., -0.0178806 ,
#         -0.59666741, -0.27126978]])

# %%
aux = list(data.words)
word_count = []

for i in data.index:
    word_count.append(len(aux[i]))
    
data['word_count'] = word_count

# %%
data.head()
# Out:
#    tweet_id                                               text  \
# 0         1  The polls are absolutely wrong! All you have t...
# 1         8   _Lai And the dangerous part? When there is pu...
# 2        19  News flash. tRump IS a politician. https://t.c...
# 3        35  #NewYorkPost published a report saying e-mails...
# 4        39   @realDonaldTrump    @JoeBiden GOP HAS APPOINT...
#
#                    user_screen_name                      created_at  \
# 0  590ecf4c5b88c57f5658f3097f32efd2  Tue Oct 20 15:11:08 +0000 2020
# 1  203afe8023cab3bb1fa15ec48c737a71  Tue Oct 20 15:10:48 +0000 2020
# 2  a708a5aef0063b7a40cd2bbbf51984c0  Tue Oct 20 15:10:10 +0000 2020
# 3  c1170c45d30c5a1c258ba52e5e8349f6  Tue Oct 20 15:09:31 +0000 2020
# 4  2d9df2e6b9ecba9c119fc674c211b5ec  Tue Oct 20 15:09:14 +0000 2020
#
#    favorite_count  retweet_count  user_followers  \
# 0               0              0               3
# 1              18              1            2502
# 2               1              0             275
# 3               1              1             106
# 4               0              0             197
#
#                                                  url  user_followers_index  \
# 0  https://twitter.com/twitter/statuses/131857045...              0.832457
# 1  https://twitter.com/twitter/statuses/131857037...              0.915293
# 2  https://twitter.com/twitter/statuses/131857020...              0.845215
# 3  https://twitter.com/twitter/statuses/131857004...              0.837466
# 4  https://twitter.com/twitter/statuses/131856997...              0.841707
#
#                                             hashtags  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  NewYorkPost, JoeBiden, HunterBiden, BREAKING, ...
# 4                                                NaN
#
#                                                words  word_count
# 0  [poll, absolut, wrong, watch, ralli, see, incr...          20
# 1  [lai, danger, part, pushback, dont, say, anyth...          18
# 2                   [news, flash, trump, politician]           4
# 3  [newyorkpost, publish, report, say, email, obt...          14
# 4  [realdonaldtrump, joebiden, gop, appoint, 14, ...          21

# %%
data.shape
# Out:
# (15000, 12)

# %%
tweets_data = data[data['word_count']!=0]

# %%
tweets_data.shape[0]
# Out:
# 14917

# %% [markdown]
# Up to here we have embedded tweets in tweets_data dataframe

# %%
tweets_data.shape[0] == len(tweet_vecs)
# Out:
# True

# %% [markdown]
# Assign vector representation to each tweet

# %%
tweets_data['tweet_vector'] = list(tweet_vecs)

tweets_data.head()
# Out:
# <ipython-input-42-f630f1795951>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tweets_data['tweet_vector'] = list(tweet_vecs)
#    tweet_id                                               text  \
# 0         1  The polls are absolutely wrong! All you have t...
# 1         8   _Lai And the dangerous part? When there is pu...
# 2        19  News flash. tRump IS a politician. https://t.c...
# 3        35  #NewYorkPost published a report saying e-mails...
# 4        39   @realDonaldTrump    @JoeBiden GOP HAS APPOINT...
#
#                    user_screen_name                      created_at  \
# 0  590ecf4c5b88c57f5658f3097f32efd2  Tue Oct 20 15:11:08 +0000 2020
# 1  203afe8023cab3bb1fa15ec48c737a71  Tue Oct 20 15:10:48 +0000 2020
# 2  a708a5aef0063b7a40cd2bbbf51984c0  Tue Oct 20 15:10:10 +0000 2020
# 3  c1170c45d30c5a1c258ba52e5e8349f6  Tue Oct 20 15:09:31 +0000 2020
# 4  2d9df2e6b9ecba9c119fc674c211b5ec  Tue Oct 20 15:09:14 +0000 2020
#
#    favorite_count  retweet_count  user_followers  \
# 0               0              0               3
# 1              18              1            2502
# 2               1              0             275
# 3               1              1             106
# 4               0              0             197
#
#                                                  url  user_followers_index  \
# 0  https://twitter.com/twitter/statuses/131857045...              0.832457
# 1  https://twitter.com/twitter/statuses/131857037...              0.915293
# 2  https://twitter.com/twitter/statuses/131857020...              0.845215
# 3  https://twitter.com/twitter/statuses/131857004...              0.837466
# 4  https://twitter.com/twitter/statuses/131856997...              0.841707
#
#                                             hashtags  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  NewYorkPost, JoeBiden, HunterBiden, BREAKING, ...
# 4                                                NaN
#
#                                                words  word_count  \
# 0  [poll, absolut, wrong, watch, ralli, see, incr...          20
# 1  [lai, danger, part, pushback, dont, say, anyth...          18
# 2                   [news, flash, trump, politician]           4
# 3  [newyorkpost, publish, report, say, email, obt...          14
# 4  [realdonaldtrump, joebiden, gop, appoint, 14, ...          21
#
#                                         tweet_vector
# 0  [-0.40646249055862427, 0.41235965862870216, -0...
# 1  [-0.3498181795132243, 0.349361029582926, -0.21...
# 2  [-0.30142234545201063, 0.3303153607994318, -0....
# 3  [-0.2622946056487438, 0.26261052994024275, -0....
# 4  [-0.2688022776772933, 0.27818502949195956, -0....

# %% [markdown]
# Now we check that vectors are correctly assigned

# %%
from numpy import linalg as LA
import numpy as np
num_tweet_vecs = len(tweet_vecs)
for i in range(num_tweet_vecs):
    if (LA.norm(tweet_vecs[i]) != LA.norm(tweets_data.iloc[i,12])):
        print(i)

# %% [markdown]
# ### Dimensionality reduction using TSNE and plot
# We will use a sample made of the 100000 first tweet vectors

# %%
import time

def reduce_dimensions(vecs):

    # reduce usint t-SNE
    tsne = TSNE(n_components=2, random_state=0,n_jobs=-1)
    vectors = tsne.fit_transform(vecs)

    x_vals = [v[0] for v in vectors]
    y_vals = [v[1] for v in vectors]
    return x_vals, y_vals

# %%
tweet_vecs_sample = tweet_vecs[:100000]
start = time.time()

x_vals, y_vals = reduce_dimensions(tweet_vecs_sample)

time.time() - start
# Out:
# 64.67360877990723

# %%
def plot_with_matplotlib(x_vals, y_vals):
    import matplotlib.pyplot as plt
    import random

    random.seed(0)

    plt.figure(figsize=(12, 12))
    plt.scatter(x_vals, y_vals)



plot_with_matplotlib(x_vals,y_vals)

# %%
plot_with_matplotlib(x_vals[:10000],y_vals[:10000])

# %%
tweets_2d = []

for i in range(len(x_vals)):
    aux = [x_vals[i],y_vals[i]]
    tweets_2d.append(aux)

# %%
tweets_2d = np.asarray(tweets_2d)

# %%
len(tweets_2d)
# Out:
# 14917

# %%
from sklearn.cluster import KMeans 
from sklearn import metrics 
from scipy.spatial.distance import cdist

# %%
distortions = [] 
inertias = [] 
mapping1 = {} 
mapping2 = {} 
K = range(1,15) 
X = tweets_2d  
for k in K: 
    #Building and fitting the model 
    kmeanModel = KMeans(n_clusters=k).fit(X) 
    kmeanModel.fit(X)     
      
    distortions.append(sum(np.min(cdist(X, kmeanModel.cluster_centers_, 
                      'euclidean'),axis=1)) / X.shape[0]) 
    inertias.append(kmeanModel.inertia_) 
  
    mapping1[k] = sum(np.min(cdist(X, kmeanModel.cluster_centers_, 
                 'euclidean'),axis=1)) / X.shape[0] 
    mapping2[k] = kmeanModel.inertia_

# %%
plt.plot(K, inertias, 'bx-') 
plt.xlabel('Values of K') 
plt.ylabel('Inertia') 
plt.title('The Elbow Method using Inertia') 
plt.show()

# %% [markdown]
# Elbow method is a common used estimate to obtain the optimal number of clusters. The criteria behind is to pick the integer after which the distortion/inertia plot start decreasing linearly. In our case we will pick 6 clusters.

# %%
from sklearn.cluster import KMeans
X = tweets_2d 
km = KMeans(n_clusters=6)
y = km.fit_predict(X)

# %%
plt.figure(figsize=(12, 12))

plt.scatter(X[y==0, 0], X[y==0, 1], s=100, c='blue', label = 'Cluster 1')
plt.scatter(X[y==1, 0], X[y==1, 1], s=100, c='red', label = 'Cluster 2')
plt.scatter(X[y==2, 0], X[y==2, 1], s=100, c='green', label = 'Cluster 3')
plt.scatter(X[y==3, 0], X[y==3, 1], s=100, c='gold', label = 'Cluster 4')
plt.scatter(X[y==4, 0], X[y==4, 1], s=100, c='magenta', label = 'Cluster 5')
plt.scatter(X[y==5, 0], X[y==5, 1], s=100, c='black', label = 'Cluster 6')



plt.xlabel('dim 1')
plt.ylabel('dim 2')
plt.legend()
plt.show()

# %%
cluster_target = y
len(cluster_target)
# Out:
# 14917

# %%
from sklearn.cluster import KMeans

X = X[0:10000]

km = KMeans(n_clusters=6,random_state=0)
y = km.fit_predict(X)

plt.figure(figsize=(12, 12))

plt.scatter(X[y==0, 0], X[y==0, 1], s=100, c='blue', label = 'Cluster 1')
plt.scatter(X[y==1, 0], X[y==1, 1], s=100, c='red', label = 'Cluster 2')
plt.scatter(X[y==2, 0], X[y==2, 1], s=100, c='green', label = 'Cluster 3')
plt.scatter(X[y==3, 0], X[y==3, 1], s=100, c='gold', label = 'Cluster 4')
plt.scatter(X[y==4, 0], X[y==4, 1], s=100, c='magenta', label = 'Cluster 5')
plt.scatter(X[y==5, 0], X[y==5, 1], s=100, c='black', label = 'Cluster 6')



plt.xlabel('dim 1')
plt.ylabel('dim 2')
plt.legend()
plt.show()

# %% [markdown]
# ## Relevant words for each cluster

# %%
embedded_tweets = tweets_data.iloc[:100000,:]
embedded_tweets['cluster'] = cluster_target

embedded_tweets.head()
# Out:
# <ipython-input-58-a1246379576b>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   embedded_tweets['cluster'] = cluster_target
#    tweet_id                                               text  \
# 0         1  The polls are absolutely wrong! All you have t...
# 1         8   _Lai And the dangerous part? When there is pu...
# 2        19  News flash. tRump IS a politician. https://t.c...
# 3        35  #NewYorkPost published a report saying e-mails...
# 4        39   @realDonaldTrump    @JoeBiden GOP HAS APPOINT...
#
#                    user_screen_name                      created_at  \
# 0  590ecf4c5b88c57f5658f3097f32efd2  Tue Oct 20 15:11:08 +0000 2020
# 1  203afe8023cab3bb1fa15ec48c737a71  Tue Oct 20 15:10:48 +0000 2020
# 2  a708a5aef0063b7a40cd2bbbf51984c0  Tue Oct 20 15:10:10 +0000 2020
# 3  c1170c45d30c5a1c258ba52e5e8349f6  Tue Oct 20 15:09:31 +0000 2020
# 4  2d9df2e6b9ecba9c119fc674c211b5ec  Tue Oct 20 15:09:14 +0000 2020
#
#    favorite_count  retweet_count  user_followers  \
# 0               0              0               3
# 1              18              1            2502
# 2               1              0             275
# 3               1              1             106
# 4               0              0             197
#
#                                                  url  user_followers_index  \
# 0  https://twitter.com/twitter/statuses/131857045...              0.832457
# 1  https://twitter.com/twitter/statuses/131857037...              0.915293
# 2  https://twitter.com/twitter/statuses/131857020...              0.845215
# 3  https://twitter.com/twitter/statuses/131857004...              0.837466
# 4  https://twitter.com/twitter/statuses/131856997...              0.841707
#
#                                             hashtags  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  NewYorkPost, JoeBiden, HunterBiden, BREAKING, ...
# 4                                                NaN
#
#                                                words  word_count  \
# 0  [poll, absolut, wrong, watch, ralli, see, incr...          20
# 1  [lai, danger, part, pushback, dont, say, anyth...          18
# 2                   [news, flash, trump, politician]           4
# 3  [newyorkpost, publish, report, say, email, obt...          14
# 4  [realdonaldtrump, joebiden, gop, appoint, 14, ...          21
#
#                                         tweet_vector  cluster
# 0  [-0.40646249055862427, 0.41235965862870216, -0...        0
# 1  [-0.3498181795132243, 0.349361029582926, -0.21...        3
# 2  [-0.30142234545201063, 0.3303153607994318, -0....        3
# 3  [-0.2622946056487438, 0.26261052994024275, -0....        2
# 4  [-0.2688022776772933, 0.27818502949195956, -0....        2

# %%
cluster_0 = embedded_tweets[embedded_tweets['cluster']==0]
model_c0 = gensim.models.Word2Vec(cluster_0.words.to_list(),min_count=1,size=300)

cluster_1 = embedded_tweets[embedded_tweets['cluster']==1]
model_c1 = gensim.models.Word2Vec(cluster_1.words.to_list(),min_count=1,size=300)

cluster_2 = embedded_tweets[embedded_tweets['cluster']==2]
model_c2 = gensim.models.Word2Vec(cluster_2.words.to_list(),min_count=1,size=300)

cluster_3 = embedded_tweets[embedded_tweets['cluster']==3]
model_c3 = gensim.models.Word2Vec(cluster_3.words.to_list(),min_count=1,size=300)

cluster_4 = embedded_tweets[embedded_tweets['cluster']==4]
model_c4 = gensim.models.Word2Vec(cluster_4.words.to_list(),min_count=1,size=300)

cluster_5 = embedded_tweets[embedded_tweets['cluster']==5]
model_c5 = gensim.models.Word2Vec(cluster_5.words.to_list(),min_count=1,size=300)

# %% [markdown]
# Now, for each cluster, let's see the top 5 most relevant keywords in the tweets.

# %%
print('Top 5 most relevant keywords for cluster:')
print(f'cluster 1: {model_c0.wv.index2entity[:5]}')
print(f'cluster 2: {model_c1.wv.index2entity[:5]}')
print(f'cluster 3: {model_c2.wv.index2entity[:5]}')
print(f'cluster 4: {model_c3.wv.index2entity[:5]}')
print(f'cluster 5: {model_c4.wv.index2entity[:5]}')
print(f'cluster 6: {model_c5.wv.index2entity[:5]}')
# Out:
# Top 5 most relevant keywords for cluster:
# cluster 1: ['trump', 'vote', 'biden', 'peopl', 'like']
# cluster 2: ['trump', 'biden', 'vote', 'joe', 'presid']
# cluster 3: ['trump', 'biden', 'vote', 'amp', 'like']
# cluster 4: ['trump', 'vote', 'republican', 'peopl', 'like']
# cluster 5: ['trump', 'biden', 'republican', 'amp', 'like']
# cluster 6: ['biden', 'trump', 'joe', 'watch', 'town']

# %% [markdown]
# ## 2nd RQ - Output Diversification
# embedded_tweets is the dataset to work with when using all 100K embedded tweets, and cluster_i contains each different cluster's tweet information.

# %% [markdown]
# 6 is the best possible number of clusters as previously explained. Now let's move to diversification.

# %%
def print_tweet_diverse(tweet, n, score, cluster):
    '''
    Print information about tweet n from the ranking in a organized format.
    
    Argument:
    tweet -- information to print
    n -- number of tweet in the ranking
    '''
    print('\nResult {} (score {:.5} : cluster {})'.format(n,score,cluster))
    print("-"*70)
    print(tweet.text)
    if isinstance(tweet.hashtags,str):
        print(f'\nHashtags: {tweet.hashtags}')
    print(f'\nTweet by user {tweet.user_screen_name}')
    print(f'\t❤️ {tweet.favorite_count}\t🔁 {tweet.retweet_count}\t📅{tweet.created_at}')
    #print(f'Hashtags:')
    print(f'Url: {tweet.url}\n')
    print("="*70)

# %%
def diversify_results(results, data, div_coef = 0.98):
    new_results = []
    for cluster in data.cluster.unique():
        sections = data[data['cluster'] == cluster]
        position = 0
        for x in results:
            if x[0] in sections.tweet_id.values:
                new_value = x[1]*(div_coef**position)
                new_results.append([x[0], new_value, cluster])
                position += 1
    new_results = sorted(new_results, key=lambda x: x[1], reverse = True)
    return new_results

# %%
def search_engine_w2v_diversified(model, data, index, coef = 0.98, tsv = False):
    query = input("Search: ")
    result = search_word2vec(query, index, model, data)
    
    #diversify
    result = diversify_results(result, data, coef)
    
    positionx= [x[0] for x in result]
    scoresx= [x[1] for x in result]
    clusterx= [x[2] for x in result]
    tweets = data[data['tweet_id'].isin(positionx)].set_index('tweet_id')
    
    to_return = pd.DataFrame()
    vars_to_return = ['text','user_screen_name','created_at','hashtags','favorite_count','retweet_count','url']
    
    print("="*70)
    for i in range(0,min(20,len(tweets)),1):
        tweet = tweets.loc[positionx[i]]
        print_tweet_diverse(tweet, i+1, scoresx[i], clusterx[i])
        
        if tsv == True:
            to_append = tweet.loc[vars_to_return]
            to_return = to_return.append(to_append,ignore_index=True)
    
    if tsv == True:
        name = str('ranking_'+query+'_coef_'+str(coef)+'.tsv')
        to_return.to_csv(name, sep = '\t', quotechar='"')

# %%
search_engine_w2v_diversified(model, embedded_tweets, index, tsv=True)
# Out:
# Search: fake news
# ======================================================================
#
# Result 1 (score 0.99907 : cluster 1)
# ----------------------------------------------------------------------
#  Why is NBC holding this event for Trump? All he does is trash NBC and MSNBC and call every report FAKE news.
#
# Tweet by user ab1e0956ff44ff4a64fa8bffc161b02f
# 	❤️ 2	🔁 0	📅Wed Oct 14 17:20:49 +0000 2020
# Url: https://twitter.com/twitter/statuses/1316428762532270081
#
# ======================================================================
#
# Result 2 (score 0.99821 : cluster 5)
# ----------------------------------------------------------------------
#  Exactly right. This was supposed to be a town hall Not a debate between President Trump and the fake news biased commentator. . I guess we should expect that. Very Sad. Trump does great when he gets to talk directly to people
#
# Tweet by user a58536ec8388d4a35add1c3bc61ea96e
# 	❤️ 1	🔁 0	📅Fri Oct 16 01:24:20 +0000 2020
# Url: https://twitter.com/twitter/statuses/1316912830197747714
#
# ======================================================================
#
# Result 3 (score 0.99639 : cluster 4)
# ----------------------------------------------------------------------
#  Trump is so confident he can walkinto a fake news trap and escapetheir snare un scathed
#
# Tweet by user 39449a5e829877df62dfd8e9e9793072
# 	❤️ 1	🔁 0	📅Fri Oct 16 01:42:51 +0000 2020
# Url: https://twitter.com/twitter/statuses/1316917489826205701
#
# ======================================================================
#
# Result 4 (score 0.99593 : cluster 2)
# ----------------------------------------------------------------------
#  The story stinks and is full of holes. This is obviously a fake news setup. Just a sign of the desperation Trump is in
#
# Tweet by user c93a902151cf29fe6b24fab7433325ca
# 	❤️ 1	🔁 0	📅Wed Oct 14 15:43:39 +0000 2020
# Url: https://twitter.com/twitter/statuses/1316404308418523137
#
# ======================================================================
#
# Result 5 (score 0.99496 : cluster 3)
# ----------------------------------------------------------------------
#      @JoeBiden Nor do you on the Biden’s...this laptop is it?  Why didn’t the FBI do anything about it?...q your conspiracy response fbi’s corrupt fake news etc
#
# Tweet by user 07f3cf6cfaf1682b183d2bd45f34e1c4
# 	❤️ 2	🔁 0	📅Fri Oct 16 19:04:25 +0000 2020
# Url: https://twitter.com/twitter/statuses/1317179610807848960
#
# ======================================================================
#
# Result 6 (score 0.99271 : cluster 0)
# ----------------------------------------------------------------------
# So glad you said this so many will believe you and nit the FAKE NEWS!! Trump 2020 https://t.co/BrNFKiGhfs
#
# Tweet by user 1d7aa265e2e0c614b5157482fddce68f
# 	❤️ 1	🔁 0	📅Fri Oct 16 00:48:25 +0000 2020
# Url: https://twitter.com/twitter/statuses/1316903793439723524
#
# ======================================================================
#
# Result 7 (score 0.97814 : cluster 5)
# ----------------------------------------------------------------------
#   You obviously have been watching fake news instead of paying attention.Trump 2020
#
# Tweet by user 055c35e7c04ac59e87c39f7551380d56
# 	❤️ 1	🔁 0	📅Wed Oct 14 16:34:26 +0000 2020
# Url: https://twitter.com/twitter/statuses/1316417089868124160
#
# ======================================================================
#
# Result 8 (score 0.97685 : cluster 1)
# ----------------------------------------------------------------------
#   FAKE NEWS !!!!!!THESE POLLS ARE A FUCKING JOKE JUST LIKE BIDEN
#
# Tweet by user d7d71e778a61ce2ddd6beb7b14b722a0
# 	❤️ 0	🔁 0	📅Tue Oct 13 15:51:41 +0000 2020
# Url: https://twitter.com/twitter/statuses/1316043940878053378
#
# ======================================================================
#
# Result 9 (score 0.974 : cluster 2)
# ----------------------------------------------------------------------
# Trump calling himself “Big T” now. Actually that’s fake news. According to Stormy Daniels Trump has a tiny mushroom shaped d**k. 🍄 https://t.co/U0ZxOEYBX8
#
# Tweet by user e0dbd01d93c6496e375da09d6ff4d8fd
# 	❤️ 0	🔁 0	📅Fri Oct 16 12:18:04 +0000 2020
# Url: https://twitter.com/twitter/statuses/1317077346189340673
#
# ======================================================================
#
# Result 10 (score 0.97216 : cluster 0)
# ----------------------------------------------------------------------
# Fake News Pal. But no matter what Trump's done it sure as hell doesn't make what the Biden crime family an dozens of swampers  GOP and Dem justified https://t.co/cGWJTmLYA3 https://t.co/9Au4PR98Rq
#
# Tweet by user c66bb5724d6b2f566e273187b342b47f
# 	❤️ 0	🔁 0	📅Mon Oct 19 05:20:52 +0000 2020
# Url: https://twitter.com/twitter/statuses/1318059517800833024
#
# ======================================================================
#
# Result 11 (score 0.97058 : cluster 3)
# ----------------------------------------------------------------------
#    _Polls _group Lol and you clowns consider 99% of polls fake because Faux News and God emperor Trump told you he's in the lead 😂😂
#
# Tweet by user bc4dffa800c37186245fc8e1bf797f4c
# 	❤️ 0	🔁 0	📅Fri Oct 16 14:22:16 +0000 2020
# Url: https://twitter.com/twitter/statuses/1317108603967463424
#
# ======================================================================
#
# Result 12 (score 0.97011 : cluster 4)
# ----------------------------------------------------------------------
# Fake news?? ANTIFA-  As part of its series of undercover videos exposing left-wing organizations like Antifa Project Veritas Radical BLM released footage claiming to show far-left Democrat activists bragging about George Soros funding and political connections.
#
# Tweet by user 13082890f16072221a0989a5b0aa6d36
# 	❤️ 0	🔁 0	📅Tue Oct 20 20:48:26 +0000 2020
# Url: https://twitter.com/twitter/statuses/1318655337466105857
#
# ======================================================================
#
# Result 13 (score 0.95676 : cluster 5)
# ----------------------------------------------------------------------
#  I'll be watching ABC Joe Biden. Why didn't FOXNews host the jackass townhall. I thought CNN MSNBC ABC etc were fake news oh he is desperate he needs all the fake news to host along with the fake people to watch.
#
# Tweet by user caecf1fdda98dd10e47f29aa20480561
# 	❤️ 0	🔁 0	📅Wed Oct 14 14:36:31 +0000 2020
# Url: https://twitter.com/twitter/statuses/1316387413208506368
#
# ======================================================================
#
# Result 14 (score 0.95659 : cluster 1)
# ----------------------------------------------------------------------
# They really are desperate because Trump and his Crime Family are losing they will attack the Bidens and spread Fake News https://t.co/GnumMuARBX
#
# Tweet by user 13284ec8e7a3deb082934e815a6f7fb3
# 	❤️ 0	🔁 0	📅Sun Oct 18 20:13:49 +0000 2020
# Url: https://twitter.com/twitter/statuses/1317921849276305408
#
# ======================================================================
#
# Result 15 (score 0.95393 : cluster 2)
# ----------------------------------------------------------------------
# Here's A Great Video on Trump Derangement Syndrome! Concerning folks who have been Brainwashed by fake news... https://t.co/UdplYjA52u
#
# Tweet by user 11596adc55137c3c91e60061f33642c8
# 	❤️ 0	🔁 0	📅Tue Oct 13 15:58:29 +0000 2020
# Url: https://twitter.com/twitter/statuses/1316045653466898436
#
# ======================================================================
#
# Result 16 (score 0.95168 : cluster 0)
# ----------------------------------------------------------------------
#  You make it seem that Fauci said Trump is undermining him but he didn’t say that . More fake news!
#
# Tweet by user 4f032c1f4752d8974259eabdfe15fe35
# 	❤️ 0	🔁 0	📅Tue Oct 13 18:31:48 +0000 2020
# Url: https://twitter.com/twitter/statuses/1316084239373348867
#
# ======================================================================
#
# Result 17 (score 0.95099 : cluster 3)
# ----------------------------------------------------------------------
# I’ll try 2 be funny and I expect to be blocked nonetheless I CANT and WONT support Donald Trump. Sorry not sorry.  I’m ready for some 1 Presidential in the office. He lost me when he made fun of the disabled reporter.  If you think it’s fake news. Ur wrong. He’s a pos. https://t.co/hNJr0bUADr
#
# Tweet by user 67cbdbbffdce79ed04d7bfb48c3b0ff4
# 	❤️ 35	🔁 0	📅Sat Oct 17 23:27:01 +0000 2020
# Url: https://twitter.com/twitter/statuses/1317608084534136832
#
# ======================================================================
#
# Result 18 (score 0.93762 : cluster 5)
# ----------------------------------------------------------------------
# So     Refuse to run actual news on hunter biden and the shady dealing him and his father were involved in but yet anything remotely negative and mostly fake stuff put out on trump gets front page news. Unreal this media bias.
#
# Tweet by user d60ee75e4e8a7965943ea16c8d07b865
# 	❤️ 0	🔁 0	📅Fri Oct 16 01:06:07 +0000 2020
# Url: https://twitter.com/twitter/statuses/1316908247916433412
#
# ======================================================================
#
# Result 19 (score 0.93714 : cluster 1)
# ----------------------------------------------------------------------
#    Fake News! Oh yeah Biden’s have a lot to answer for! Things are just getting started with the Biden’s!
#
# Tweet by user 9eb4cc9fac9ef4119cf700d6eddc8205
# 	❤️ 4	🔁 0	📅Thu Oct 15 17:56:56 +0000 2020
# Url: https://twitter.com/twitter/statuses/1316800237609062400
#
# ======================================================================
#
# Result 20 (score 0.93427 : cluster 2)
# ----------------------------------------------------------------------
# The fact that Trump is tweet literal fake new from the Babylon bee which is a news satire site to try and have a “gotcha” moment is hilarious
#
# Tweet by user 4a5c00a769557cc0584b7cf8fec93585
# 	❤️ 0	🔁 0	📅Fri Oct 16 17:26:53 +0000 2020
# Url: https://twitter.com/twitter/statuses/1317155062724972544
#
# ======================================================================

# %%
search_engine_w2v_diversified(model, embedded_tweets, index, coef=1, tsv=True)
# Out:
# Search: fake news
# ======================================================================
#
# Result 1 (score 0.99907 : cluster 1)
# ----------------------------------------------------------------------
#  Why is NBC holding this event for Trump? All he does is trash NBC and MSNBC and call every report FAKE news.
#
# Tweet by user ab1e0956ff44ff4a64fa8bffc161b02f
# 	❤️ 2	🔁 0	📅Wed Oct 14 17:20:49 +0000 2020
# Url: https://twitter.com/twitter/statuses/1316428762532270081
#
# ======================================================================
#
# Result 2 (score 0.99821 : cluster 5)
# ----------------------------------------------------------------------
#  Exactly right. This was supposed to be a town hall Not a debate between President Trump and the fake news biased commentator. . I guess we should expect that. Very Sad. Trump does great when he gets to talk directly to people
#
# Tweet by user a58536ec8388d4a35add1c3bc61ea96e
# 	❤️ 1	🔁 0	📅Fri Oct 16 01:24:20 +0000 2020
# Url: https://twitter.com/twitter/statuses/1316912830197747714
#
# ======================================================================
#
# Result 3 (score 0.9981 : cluster 5)
# ----------------------------------------------------------------------
#   You obviously have been watching fake news instead of paying attention.Trump 2020
#
# Tweet by user 055c35e7c04ac59e87c39f7551380d56
# 	❤️ 1	🔁 0	📅Wed Oct 14 16:34:26 +0000 2020
# Url: https://twitter.com/twitter/statuses/1316417089868124160
#
# ======================================================================
#
# Result 4 (score 0.99678 : cluster 1)
# ----------------------------------------------------------------------
#   FAKE NEWS !!!!!!THESE POLLS ARE A FUCKING JOKE JUST LIKE BIDEN
#
# Tweet by user d7d71e778a61ce2ddd6beb7b14b722a0
# 	❤️ 0	🔁 0	📅Tue Oct 13 15:51:41 +0000 2020
# Url: https://twitter.com/twitter/statuses/1316043940878053378
#
# ======================================================================
#
# Result 5 (score 0.99639 : cluster 4)
# ----------------------------------------------------------------------
#  Trump is so confident he can walkinto a fake news trap and escapetheir snare un scathed
#
# Tweet by user 39449a5e829877df62dfd8e9e9793072
# 	❤️ 1	🔁 0	📅Fri Oct 16 01:42:51 +0000 2020
# Url: https://twitter.com/twitter/statuses/1316917489826205701
#
# ======================================================================
#
# Result 6 (score 0.99621 : cluster 5)
# ----------------------------------------------------------------------
#  I'll be watching ABC Joe Biden. Why didn't FOXNews host the jackass townhall. I thought CNN MSNBC ABC etc were fake news oh he is desperate he needs all the fake news to host along with the fake people to watch.
#
# Tweet by user caecf1fdda98dd10e47f29aa20480561
# 	❤️ 0	🔁 0	📅Wed Oct 14 14:36:31 +0000 2020
# Url: https://twitter.com/twitter/statuses/1316387413208506368
#
# ======================================================================
#
# Result 7 (score 0.9962 : cluster 5)
# ----------------------------------------------------------------------
# So     Refuse to run actual news on hunter biden and the shady dealing him and his father were involved in but yet anything remotely negative and mostly fake stuff put out on trump gets front page news. Unreal this media bias.
#
# Tweet by user d60ee75e4e8a7965943ea16c8d07b865
# 	❤️ 0	🔁 0	📅Fri Oct 16 01:06:07 +0000 2020
# Url: https://twitter.com/twitter/statuses/1316908247916433412
#
# ======================================================================
#
# Result 8 (score 0.99603 : cluster 1)
# ----------------------------------------------------------------------
# They really are desperate because Trump and his Crime Family are losing they will attack the Bidens and spread Fake News https://t.co/GnumMuARBX
#
# Tweet by user 13284ec8e7a3deb082934e815a6f7fb3
# 	❤️ 0	🔁 0	📅Sun Oct 18 20:13:49 +0000 2020
# Url: https://twitter.com/twitter/statuses/1317921849276305408
#
# ======================================================================
#
# Result 9 (score 0.99593 : cluster 2)
# ----------------------------------------------------------------------
#  The story stinks and is full of holes. This is obviously a fake news setup. Just a sign of the desperation Trump is in
#
# Tweet by user c93a902151cf29fe6b24fab7433325ca
# 	❤️ 1	🔁 0	📅Wed Oct 14 15:43:39 +0000 2020
# Url: https://twitter.com/twitter/statuses/1316404308418523137
#
# ======================================================================
#
# Result 10 (score 0.99569 : cluster 1)
# ----------------------------------------------------------------------
#    Fake News! Oh yeah Biden’s have a lot to answer for! Things are just getting started with the Biden’s!
#
# Tweet by user 9eb4cc9fac9ef4119cf700d6eddc8205
# 	❤️ 4	🔁 0	📅Thu Oct 15 17:56:56 +0000 2020
# Url: https://twitter.com/twitter/statuses/1316800237609062400
#
# ======================================================================
#
# Result 11 (score 0.99556 : cluster 5)
# ----------------------------------------------------------------------
# Is Biden taking dementia medication? Think this is something Americans should know? Shame on Jill Biden! And defund fake news!!
#
# Tweet by user 8c13db7f762a524c5304ab307c7f8830
# 	❤️ 0	🔁 0	📅Tue Oct 13 17:57:59 +0000 2020
# Url: https://twitter.com/twitter/statuses/1316075729080254469
#
# ======================================================================
#
# Result 12 (score 0.99523 : cluster 1)
# ----------------------------------------------------------------------
# @realDonaldTrump Don't watch Fox news. It's fake news!!  n . I challenge u turn off fox turn on the real news n see what nightmare we're in under Trump. We're in a crisis n I think most AMERiCA knows it
#
# Tweet by user 4bac803c21ce8f211bcedc65aff768e5
# 	❤️ 0	🔁 0	📅Wed Oct 14 23:50:19 +0000 2020
# Url: https://twitter.com/twitter/statuses/1316526783127224320
#
# ======================================================================
#
# Result 13 (score 0.99496 : cluster 3)
# ----------------------------------------------------------------------
#      @JoeBiden Nor do you on the Biden’s...this laptop is it?  Why didn’t the FBI do anything about it?...q your conspiracy response fbi’s corrupt fake news etc
#
# Tweet by user 07f3cf6cfaf1682b183d2bd45f34e1c4
# 	❤️ 2	🔁 0	📅Fri Oct 16 19:04:25 +0000 2020
# Url: https://twitter.com/twitter/statuses/1317179610807848960
#
# ======================================================================
#
# Result 14 (score 0.99489 : cluster 1)
# ----------------------------------------------------------------------
#   @JoeBiden Where’s the Biden crowd ?If Sleepy 💤 Joe is having a Biden Rally there aught to be Biden supporters on hand chanting for him not Four More Years ! Look 👀 like he’s putting money in a empty whole to me ! No way polls could be correct Fake News you are just protecting your Ad $$ https://t.co/C2olxnQSkK
#
# Tweet by user 0f0c3d118260c42c4ece86e2dbc67ebb
# 	❤️ 2	🔁 0	📅Tue Oct 13 14:57:47 +0000 2020
# Url: https://twitter.com/twitter/statuses/1316030376976871425
#
# ======================================================================
#
# Result 15 (score 0.99452 : cluster 5)
# ----------------------------------------------------------------------
#    They are called the silent majority and Trump is winning in front of ur noses like a landslide. Watch it. Of course the reason it surprises you is because you wont see it in CNN remember when we have warned you about Fake News? That’s exactly what it means. #Trump2020 😬
#
# Hashtags: Trump2020
#
# Tweet by user c3deb8e749a4abbaf50e398ffcfc95ce
# 	❤️ 2	🔁 0	📅Tue Oct 20 04:05:53 +0000 2020
# Url: https://twitter.com/twitter/statuses/1318403038911004673
#
# ======================================================================
#
# Result 16 (score 0.99437 : cluster 1)
# ----------------------------------------------------------------------
# Kamala is interviewing Judge Barrett right now... live on TV. No fake news. Tune in and see what you think. No spin... it’s live!
#
# Tweet by user fb041b2c2b5ceca5d86f8cc2b7b9eb56
# 	❤️ 0	🔁 0	📅Tue Oct 13 23:23:00 +0000 2020
# Url: https://twitter.com/twitter/statuses/1316157518964457474
#
# ======================================================================
#
# Result 17 (score 0.99388 : cluster 2)
# ----------------------------------------------------------------------
# Trump calling himself “Big T” now. Actually that’s fake news. According to Stormy Daniels Trump has a tiny mushroom shaped d**k. 🍄 https://t.co/U0ZxOEYBX8
#
# Tweet by user e0dbd01d93c6496e375da09d6ff4d8fd
# 	❤️ 0	🔁 0	📅Fri Oct 16 12:18:04 +0000 2020
# Url: https://twitter.com/twitter/statuses/1317077346189340673
#
# ======================================================================
#
# Result 18 (score 0.99342 : cluster 5)
# ----------------------------------------------------------------------
# Joe Biden could stand in the middle of 5th Avenue and shoot someone and I would still vote for him! #HunterBiden story is fake. Steve Bannon and Giuliani are involved. Enough said! The NY Post is a Fox News wannabe!
#
# Hashtags: HunterBiden
#
# Tweet by user c713cb9d138fa5280576c1fe3a0d1a1b
# 	❤️ 28	🔁 8	📅Wed Oct 14 20:04:40 +0000 2020
# Url: https://twitter.com/twitter/statuses/1316469995019268096
#
# ======================================================================
#
# Result 19 (score 0.99327 : cluster 2)
# ----------------------------------------------------------------------
# Here's A Great Video on Trump Derangement Syndrome! Concerning folks who have been Brainwashed by fake news... https://t.co/UdplYjA52u
#
# Tweet by user 11596adc55137c3c91e60061f33642c8
# 	❤️ 0	🔁 0	📅Tue Oct 13 15:58:29 +0000 2020
# Url: https://twitter.com/twitter/statuses/1316045653466898436
#
# ======================================================================
#
# Result 20 (score 0.99271 : cluster 0)
# ----------------------------------------------------------------------
# So glad you said this so many will believe you and nit the FAKE NEWS!! Trump 2020 https://t.co/BrNFKiGhfs
#
# Tweet by user 1d7aa265e2e0c614b5157482fddce68f
# 	❤️ 1	🔁 0	📅Fri Oct 16 00:48:25 +0000 2020
# Url: https://twitter.com/twitter/statuses/1316903793439723524
#
# ======================================================================
